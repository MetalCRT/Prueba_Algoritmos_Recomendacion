# %%
#Instalamos las librerias indicadas
# !python3 -m ensurepip --upgrade
# !pip install jupyter
# !git clone https://github.com/RUCAIBox/RecBole.git && cd RecBole
# !pip install -e . --verbose
# Out:
# Looking in links: /var/folders/9x/3wsn28h13yxfzlwnz349kx_40000gn/T/tmpyzwjm12d
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 3.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [jupyter]
# ...
# Clonando en 'RecBole'...
# remote: Enumerating objects: 23604, done.
# remote: Counting objects: 100% (3559/3559), done.
# remote: Compressing objects: 100% (367/367), done.
# remote: Total 23604 (delta 3320), reused 3192 (delta 3192), pack-reused 20045 (from 2)
# Recibiendo objetos: 100% (23604/23604), 19.51 MiB | 1.46 MiB/s, listo.
# Resolviendo deltas: 100% (15667/15667), listo.
# Using pip 25.2 from /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pip (python 3.10)
# Obtaining file:///Users/gmedel/Documents/Universidad/LaboratorioAlgoritmos
# ERROR: file:///Users/gmedel/Documents/Universidad/LaboratorioAlgoritmos does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
#Creamos parametros
content_a = """# dataset config : Knowledge-based Recommendation
USER_ID_FIELD: user_id
ITEM_ID_FIELD: item_id
HEAD_ENTITY_ID_FIELD: head_id
TAIL_ENTITY_ID_FIELD: tail_id
RELATION_ID_FIELD: relation_id
ENTITY_ID_FIELD: entity_id
load_col:
    inter: [user_id, item_id]
    kg: [head_id, relation_id, tail_id]
    link: [item_id, entity_id]

# model config
embedding_size: 64
kg_embedding_size: 64
reg_weights: [1e-02,1e-02]

# Training and evaluation config
eval_args:
   split: {'RS': [0.8, 0.1, 0.1]}
   group_by: user
   order: RO
   mode: full
metrics: ['Recall', 'MRR', 'NDCG', 'Hit', 'Precision']
valid_metric: mrr@10
topk: 10
"""

content_b = """# dataset config : Context-aware Recommendation
load_col:
    inter: ['user_id', 'item_id', 'rating', 'timestamp']
    user: ['user_id', 'age', 'gender', 'occupation']
    item: ['item_id', 'release_year', 'class']
threshold: {'rating': 4}
normalize_all: True

# model config
embedding_size: 10

# Training and evaluation config
epochs: 500
train_batch_size: 4096
eval_batch_size: 4096
eval_args:
  split: {'RS':[0.8,0.1,0.1]}
  order: RO
  group_by: ~
  mode: labeled
train_neg_sample_args:
  distribution: uniform
  sample_num: 5
  dynamic: True
  candidate_num: 5
metrics: ['RMSE']
valid_metric: RMSE
"""

with open("test_ndcg_precision.yaml", "w") as f:
    f.write(content_a)

with open("test_rmse.yaml", "w") as f:
    f.write(content_b)

# %%
# Corremos el test utilizando los parametros NDCG y Precision y el modelo LightGCN
# !python3 RecBole/run_recbole.py --model=LightGCN --config_files=test_ndcg_precision.yaml
# Out:
# 12 Aug 03:08    INFO  ['RecBole/run_recbole.py', '--model=LightGCN', '--config_files=test_ndcg_precision.yaml']
# 12 Aug 03:08    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /Users/gmedel/Documents/Universidad/LaboratorioAlgoritmos/RecBole/recbole/config/../dataset_example/ml-100k
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# ...

# %%
# Corremos el test utilizando los parametros RMSE y el modelo LightGCN

# !python3 RecBole/run_recbole.py --model=LightGCN --config_files=test_rmse.yaml
# Out:
# 12 Aug 03:09    INFO  ['RecBole/run_recbole.py', '--model=LightGCN', '--config_files=test_rmse.yaml']
# 12 Aug 03:09    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /Users/gmedel/Documents/Universidad/LaboratorioAlgoritmos/RecBole/recbole/config/../dataset_example/ml-100k
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 500
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 5, 'dynamic': True, 'candidate_num': 5, 'alpha': 1.0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# ...

# %%
# Corremos el test utilizando los parametros NDCG y Precision y el modelo BPR para comparar

# !python3 RecBole/run_recbole.py --model=BPR --config_files=test_ndcg_precision.yaml
# Out:
# 12 Aug 17:08    INFO  ['RecBole/run_recbole.py', '--model=BPR', '--config_files=test_ndcg_precision.yaml']
# 12 Aug 17:08    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /Users/gmedel/Documents/Universidad/LaboratorioAlgoritmos/RecBole/recbole/config/../dataset_example/ml-100k
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 300
# train_batch_size = 2048
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 1, 'alpha': 1.0, 'dynamic': False, 'candidate_num': 0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# ...

# %%
# Corremos el test utilizando los parametros RMSE y el modelo BPR para comparar

# !python3 RecBole/run_recbole.py --model=BPR --config_files=test_rmse.yaml
# Out:
# 12 Aug 17:09    INFO  ['RecBole/run_recbole.py', '--model=BPR', '--config_files=test_rmse.yaml']
# 12 Aug 17:09    INFO
# General Hyper Parameters:
# gpu_id = 0
# use_gpu = True
# seed = 2020
# state = INFO
# reproducibility = True
# data_path = /Users/gmedel/Documents/Universidad/LaboratorioAlgoritmos/RecBole/recbole/config/../dataset_example/ml-100k
# checkpoint_dir = saved
# show_progress = True
# save_dataset = False
# dataset_save_path = None
# save_dataloaders = False
# dataloaders_save_path = None
# log_wandb = False
#
# Training Hyper Parameters:
# epochs = 500
# train_batch_size = 4096
# learner = adam
# learning_rate = 0.001
# train_neg_sample_args = {'distribution': 'uniform', 'sample_num': 5, 'dynamic': True, 'candidate_num': 5, 'alpha': 1.0}
# eval_step = 1
# stopping_step = 10
# clip_grad_norm = None
# weight_decay = 0.0
# loss_decimal_place = 4
#
# Evaluation Hyper Parameters:
# ...
